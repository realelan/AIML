# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text

# Step 1: Load Excel dataset
data = pd.read_excel("iris.xlsx")

# Step 2: Separate features and target
X = data.drop("species", axis=1)
y = data["species"]

# Step 3: Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Step 4: Train Decision Tree using ID3 (entropy)
dt_classifier = DecisionTreeClassifier(criterion="entropy", random_state=42)
dt_classifier.fit(X_train, y_train)

# Step 5: Evaluate the model
accuracy = dt_classifier.score(X_test, y_test)
print("Accuracy:", accuracy)

# Step 6: Display decision tree rules
tree_rules = export_text(dt_classifier, feature_names=list(X.columns))
print("\nDecision Tree Rules:\n")
print(tree_rules)

# Step 7: Classify a new sample (with column names to avoid warning)
new_sample = pd.DataFrame(
    [[5.1, 3.5, 1.4, 0.2]],
    columns=["sepal_length", "sepal_width", "petal_length", "petal_width"]
)

predicted_class = dt_classifier.predict(new_sample)

print("\nPredicted Species:", predicted_class[0])
# Out:
# Accuracy: 0.9777777777777777
#
# Decision Tree Rules:
#
# |--- petal_length <= 2.45
# |   |--- class: setosa
# |--- petal_length >  2.45
# |   |--- petal_length <= 4.75
# |   |   |--- petal_width <= 1.60
# |   |   |   |--- class: versicolor
# |   |   |--- petal_width >  1.60
# |   |   |   |--- class: virginica
# |   |--- petal_length >  4.75
# |   |   |--- petal_length <= 5.15
# |   |   |   |--- petal_width <= 1.75
# |   |   |   |   |--- sepal_width <= 2.35
# |   |   |   |   |   |--- class: virginica
# |   |   |   |   |--- sepal_width >  2.35
# |   |   |   |   |   |--- petal_length <= 5.05
# |   |   |   |   |   |   |--- class: versicolor
# |   |   |   |   |   |--- petal_length >  5.05
# |   |   |   |   |   |   |--- sepal_length <= 6.15
# |   |   |   |   |   |   |   |--- class: versicolor
# |   |   |   |   |   |   |--- sepal_length >  6.15
# |   |   |   |   |   |   |   |--- class: virginica
# |   |   |   |--- petal_width >  1.75
# |   |   |   |   |--- sepal_width <= 3.10
# ...
